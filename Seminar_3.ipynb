# %% [markdown]
# <a href="https://colab.research.google.com/github/Zabaluna/HW-Python/blob/analytics/Seminar_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1

# %%
import pandas as pd


df = pd.read_csv('laptop_price.csv')
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %% [markdown]
# ### Задание 1.1
#
#  Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU (Intel, AMD и т.д)

# %%
f = lambda x: str(x).split()[0]
df['Cpu_Company'] = df['Cpu'].apply(f) # x.split()[0]
df.head(50)
# Out:
#     laptop_ID Company                                    Product  \
# 0           1   Apple                                MacBook Pro
# 1           2   Apple                                Macbook Air
# 2           3      HP                                     250 G6
# 3           4   Apple                                MacBook Pro
# 4           5   Apple                                MacBook Pro
# 5           6    Acer                                   Aspire 3
# 6           7   Apple                                MacBook Pro
# 7           8   Apple                                Macbook Air
# 8           9    Asus                            ZenBook UX430UN
# 9          10    Acer                                    Swift 3
# 10         11      HP                                     250 G6
# 11         12      HP                                     250 G6
# 12         13   Apple                                MacBook Pro
# 13         14    Dell                              Inspiron 3567
# 14         15   Apple                                MacBook 12"
# 15         16   Apple                                MacBook Pro
# 16         17    Dell                              Inspiron 3567
# 17         18   Apple                                MacBook Pro
# 18         19  Lenovo                          IdeaPad 320-15IKB
# 19         20    Dell                                     XPS 13
# 20         21    Asus                            Vivobook E200HA
# 21         22  Lenovo                         Legion Y520-15IKBN
# 22         23      HP                                     255 G6
# 23         24    Dell                              Inspiron 5379
# 24         25      HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25         26    Dell                              Inspiron 3567
# 26         27   Apple                                MacBook Air
# 27         28    Dell                              Inspiron 5570
# 28         29    Dell                              Latitude 5590
# 29         30      HP                                ProBook 470
# 30         31   Chuwi                              LapBook 15.6"
# 31         32    Asus       E402WA-GA010T (E2-6110/2GB/32GB/W10)
# 32         33      HP       17-ak001nv (A6-9220/4GB/500GB/Radeon
# 33         34    Dell                                     XPS 13
# 34         35   Apple                                MacBook Air
# 35         36  Lenovo                         IdeaPad 120S-14IAP
# 36         37    Acer                                   Aspire 3
# 37         38    Dell                              Inspiron 5770
# 38         39      HP                                     250 G6
# 39         40      HP                                ProBook 450
# 40         41    Asus  X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)
# 41         42    Dell                              Inspiron 7577
# 42         43    Asus     X542UQ-GO005 (i5-7200U/8GB/1TB/GeForce
# 43         44    Acer                            Aspire A515-51G
# 44         45    Dell                              Inspiron 7773
# 45         46   Apple                                MacBook Pro
# 46         47  Lenovo                          IdeaPad 320-15ISK
# 47         48    Asus                                  Rog Strix
# 48         49    Dell                              Inspiron 3567
# 49         50    Asus       X751NV-TY001T (N4200/4GB/1TB/GeForce
#
#               TypeName  Inches                                   Cpu   Ram  \
# 0            Ultrabook    13.3                  Intel Core i5 2.3GHz   8GB
# 1            Ultrabook    13.3                  Intel Core i5 1.8GHz   8GB
# 2             Notebook    15.6            Intel Core i5 7200U 2.5GHz   8GB
# 3            Ultrabook    15.4                  Intel Core i7 2.7GHz  16GB
# 4            Ultrabook    13.3                  Intel Core i5 3.1GHz   8GB
# 5             Notebook    15.6               AMD A9-Series 9420 3GHz   4GB
# 6            Ultrabook    15.4                  Intel Core i7 2.2GHz  16GB
# 7            Ultrabook    13.3                  Intel Core i5 1.8GHz   8GB
# 8            Ultrabook    14.0            Intel Core i7 8550U 1.8GHz  16GB
# 9            Ultrabook    14.0            Intel Core i5 8250U 1.6GHz   8GB
# 10            Notebook    15.6            Intel Core i5 7200U 2.5GHz   4GB
# 11            Notebook    15.6              Intel Core i3 6006U 2GHz   4GB
# 12           Ultrabook    15.4                  Intel Core i7 2.8GHz  16GB
# 13            Notebook    15.6              Intel Core i3 6006U 2GHz   4GB
# 14           Ultrabook    12.0                Intel Core M m3 1.2GHz   8GB
# 15           Ultrabook    13.3                  Intel Core i5 2.3GHz   8GB
# 16            Notebook    15.6            Intel Core i7 7500U 2.7GHz   8GB
# 17           Ultrabook    15.4                  Intel Core i7 2.9GHz  16GB
# 18            Notebook    15.6            Intel Core i3 7100U 2.4GHz   8GB
# 19           Ultrabook    13.3            Intel Core i5 8250U 1.6GHz   8GB
# 20             Netbook    11.6           Intel Atom x5-Z8350 1.44GHz   2GB
# 21              Gaming    15.6           Intel Core i5 7300HQ 2.5GHz   8GB
# 22            Notebook    15.6          AMD E-Series E2-9000e 1.5GHz   4GB
# 23  2 in 1 Convertible    13.3            Intel Core i5 8250U 1.6GHz   8GB
# 24           Ultrabook    15.6            Intel Core i7 8550U 1.8GHz   8GB
# 25            Notebook    15.6              Intel Core i3 6006U 2GHz   4GB
# 26           Ultrabook    13.3                  Intel Core i5 1.6GHz   8GB
# 27            Notebook    15.6            Intel Core i5 8250U 1.6GHz   8GB
# 28           Ultrabook    15.6            Intel Core i7 8650U 1.9GHz   8GB
# 29            Notebook    17.3            Intel Core i5 8250U 1.6GHz   8GB
# 30            Notebook    15.6           Intel Atom x5-Z8300 1.44GHz   4GB
# 31            Notebook    14.0           AMD E-Series E2-6110 1.5GHz   2GB
# 32            Notebook    17.3             AMD A6-Series 9220 2.5GHz   4GB
# 33           Ultrabook    13.3            Intel Core i7 8550U 1.8GHz  16GB
# 34           Ultrabook    13.3                  Intel Core i5 1.6GHz   8GB
# 35            Notebook    14.0  Intel Celeron Dual Core N3350 1.1GHz   4GB
# 36            Notebook    15.6            Intel Core i3 7130U 2.7GHz   4GB
# 37            Notebook    17.3            Intel Core i5 8250U 1.6GHz   8GB
# 38            Notebook    15.6            Intel Core i5 7200U 2.5GHz   4GB
# 39            Notebook    15.6            Intel Core i5 8250U 1.6GHz   8GB
# 40            Notebook    15.6              Intel Core i3 6006U 2GHz   4GB
# 41              Gaming    15.6           Intel Core i7 7700HQ 2.8GHz  16GB
# 42            Notebook    15.6            Intel Core i5 7200U 2.5GHz   8GB
# 43            Notebook    15.6            Intel Core i5 8250U 1.6GHz   4GB
# 44  2 in 1 Convertible    17.3            Intel Core i5 8250U 1.6GHz  12GB
# 45           Ultrabook    13.3                  Intel Core i5 2.0GHz   8GB
# 46            Notebook    15.6              Intel Core i3 6006U 2GHz   4GB
# 47              Gaming    17.3                   AMD Ryzen 1700 3GHz   8GB
# 48            Notebook    15.6            Intel Core i5 7200U 2.5GHz   4GB
# 49            Notebook    17.3  Intel Pentium Quad Core N4200 1.1GHz   4GB
#
#                              Gpu       OpSys  Weight  Price_euros Cpu_Company  \
# 0   Intel Iris Plus Graphics 640       macOS    1.37      1339.69       Intel
# 1         Intel HD Graphics 6000       macOS    1.34       898.94       Intel
# 2          Intel HD Graphics 620       No OS    1.86       575.00       Intel
# 3             AMD Radeon Pro 455       macOS    1.83      2537.45       Intel
# 4   Intel Iris Plus Graphics 650       macOS    1.37      1803.60       Intel
# 5                  AMD Radeon R5  Windows 10    2.10       400.00         AMD
# 6        Intel Iris Pro Graphics    Mac OS X    2.04      2139.97       Intel
# 7         Intel HD Graphics 6000       macOS    1.34      1158.70       Intel
# 8           Nvidia GeForce MX150  Windows 10    1.30      1495.00       Intel
# 9         Intel UHD Graphics 620  Windows 10    1.60       770.00       Intel
# 10         Intel HD Graphics 620       No OS    1.86       393.90       Intel
# 11         Intel HD Graphics 520       No OS    1.86       344.99       Intel
# 12            AMD Radeon Pro 555       macOS    1.83      2439.97       Intel
# 13            AMD Radeon R5 M430  Windows 10    2.20       498.90       Intel
# 14         Intel HD Graphics 615       macOS    0.92      1262.40       Intel
# 15  Intel Iris Plus Graphics 640       macOS    1.37      1518.55       Intel
# 16            AMD Radeon R5 M430  Windows 10    2.20       745.00       Intel
# 17            AMD Radeon Pro 560       macOS    1.83      2858.00       Intel
# 18          Nvidia GeForce 940MX       No OS    2.20       499.00       Intel
# 19        Intel UHD Graphics 620  Windows 10    1.22       979.00       Intel
# 20         Intel HD Graphics 400  Windows 10    0.98       191.90       Intel
# 21       Nvidia GeForce GTX 1050  Windows 10    2.50       999.00       Intel
# 22                 AMD Radeon R2       No OS    1.86       258.00         AMD
# 23        Intel UHD Graphics 620  Windows 10    1.62       819.00       Intel
# 24         Intel HD Graphics 620  Windows 10    1.91       659.00       Intel
# 25         Intel HD Graphics 520  Windows 10    2.30       418.64       Intel
# 26        Intel HD Graphics 6000    Mac OS X    1.35      1099.00       Intel
# 27                AMD Radeon 530  Windows 10    2.20       800.00       Intel
# 28        Intel UHD Graphics 620  Windows 10    1.88      1298.00       Intel
# 29          Nvidia GeForce 930MX  Windows 10    2.50       896.00       Intel
# 30             Intel HD Graphics  Windows 10    1.89       244.99       Intel
# 31                 AMD Radeon R2  Windows 10    1.65       199.00         AMD
# 32                AMD Radeon 530  Windows 10    2.71       439.00         AMD
# 33        Intel UHD Graphics 620  Windows 10    1.20      1869.00       Intel
# 34        Intel HD Graphics 6000    Mac OS X    1.35       998.00       Intel
# 35         Intel HD Graphics 500  Windows 10    1.44       249.00       Intel
# 36         Intel HD Graphics 620       Linux    2.10       367.00       Intel
# 37                AMD Radeon 530  Windows 10    2.80       979.00       Intel
# 38         Intel HD Graphics 620  Windows 10    1.86       488.69       Intel
# 39         Nvidia GeForce 930MX   Windows 10    2.10       879.00       Intel
# 40         Intel HD Graphics 620       Linux    2.00       389.00       Intel
# 41       Nvidia GeForce GTX 1060  Windows 10    2.65      1499.00       Intel
# 42          Nvidia GeForce 940MX       Linux    2.30       522.99       Intel
# 43        Intel UHD Graphics 620  Windows 10    2.20       682.00       Intel
# 44          Nvidia GeForce 150MX  Windows 10    2.77       999.00       Intel
# 45       Intel Iris Graphics 540       macOS    1.37      1419.00       Intel
# 46         Intel HD Graphics 520       No OS    2.20       369.00       Intel
# 47             AMD Radeon RX 580  Windows 10    3.20      1299.00         AMD
# 48            AMD Radeon R5 M430  Windows 10    2.30       639.00       Intel
# 49          Nvidia GeForce 920MX  Windows 10    2.80       466.00       Intel
#
#     Memory_Amount   Memory_Type  SSD
# 0             128           SSD    1
# 1             128  FlashStorage    0
# 2             256           SSD    1
# 3             512           SSD    1
# 4             256           SSD    1
# 5             500           HDD    0
# 6             256  FlashStorage    0
# 7             256  FlashStorage    0
# 8             512           SSD    1
# 9             256           SSD    1
# 10            500           HDD    0
# 11            500           HDD    0
# 12            256           SSD    1
# 13            256           SSD    1
# 14            256           SSD    1
# 15            256           SSD    1
# 16            256           SSD    1
# 17            512           SSD    1
# 18           1024           HDD    0
# 19            128           SSD    1
# 20             32  FlashStorage    0
# 21            128           HDD    0
# 22            500           HDD    0
# 23            256           SSD    1
# 24            256           SSD    1
# 25           1024           HDD    0
# 26            128  FlashStorage    0
# 27            256           SSD    1
# 28            256           SSD    1
# 29           1024           HDD    0
# 30             64  FlashStorage    0
# 31             32  FlashStorage    0
# 32            500           HDD    0
# 33            512           SSD    1
# 34            256  FlashStorage    0
# 35             64  FlashStorage    0
# 36           1024           HDD    0
# 37            128           HDD    0
# 38           1024           HDD    0
# 39            256           SSD    1
# 40           1024           HDD    0
# 41            256           HDD    0
# 42           1024           HDD    0
# 43            256           SSD    1
# 44           1024           HDD    0
# 45            256           SSD    1
# 46            128           SSD    1
# 47            256           HDD    0
# 48            256           SSD    1
# 49           1024           HDD    0

# %% [markdown]
# ### Задание 1.2
#
# Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя (128, 1024, 256 и т.д.)

# %%
def convert_to_gb(x):
    memory = x.split()[0]
    if memory.endswith("GB"):
        res = memory.replace("GB", "")
    elif memory.endswith("TB"):
        res = float(memory.replace("TB", "")) * 1024
    return int(res)


df['Memory_Amount'] = df['Memory'].apply(convert_to_gb)
df['Memory_Amount']

# %% [markdown]
# ### Задание 1.3
#
# Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)

# %%
def convert_to_type(x):
    type_memory = x.replace(" ", "").split("B")[-1]
    return type_memory


df['Memory_Type'] = df['Memory'].apply(convert_to_type)
df['Memory_Type']
# Out:
# ['М', 'м', ' мыл', ' р', 'му']
# 0                SSD
# 1       FlashStorage
# 2                SSD
# 3                SSD
# 4                SSD
#             ...
# 1298             SSD
# 1299             SSD
# 1300    FlashStorage
# 1301             HDD
# 1302             HDD
# Name: Memory_Type, Length: 1303, dtype: object

# %% [markdown]
# ### Задание 1.4
# Удалите признаки Memory и ScreenResolution

# %%
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type
# 0  1.37kg      1339.69       Intel            128           SSD
# 1  1.34kg       898.94       Intel            128  FlashStorage
# 2  1.86kg       575.00       Intel            256           SSD
# 3  1.83kg      2537.45       Intel            512           SSD
# 4  1.37kg      1803.60       Intel            256           SSD

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ### Задание 2.1
#
# Создайте признак SSD, который изначально равен 0

# %%
df['SSD'] = 0
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type  SSD
# 0  1.37kg      1339.69       Intel            128           SSD    0
# 1  1.34kg       898.94       Intel            128  FlashStorage    0
# 2  1.86kg       575.00       Intel            256           SSD    0
# 3  1.83kg      2537.45       Intel            512           SSD    0
# 4  1.37kg      1803.60       Intel            256           SSD    0

# %% [markdown]
# ### Задание 2.2
#
# Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD

# %%
df.loc[df['Memory_Type'] == 'SSD', 'SSD'] = 1
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type  SSD
# 0  1.37kg      1339.69       Intel            128           SSD    1
# 1  1.34kg       898.94       Intel            128  FlashStorage    0
# 2  1.86kg       575.00       Intel            256           SSD    1
# 3  1.83kg      2537.45       Intel            512           SSD    1
# 4  1.37kg      1803.60       Intel            256           SSD    1

# %% [markdown]
# ### Задание 2.3
#
# Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
df['Weight'] = df['Weight'].str.replace("kg", "")
df['Weight'] = df['Weight'].astype('float')
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type  SSD
# 0    1.37      1339.69       Intel            128           SSD    1
# 1    1.34       898.94       Intel            128  FlashStorage    0
# 2    1.86       575.00       Intel            256           SSD    1
# 3    1.83      2537.45       Intel            512           SSD    1
# 4    1.37      1803.60       Intel            256           SSD    1

# %% [markdown]
# ## Задание 3
#
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
#     'client_id': [45, 32, 67, 33, 43],
#     'laptop_id': [506, 398, 710, 120, 1999]
# })
# laptop_id - это индексы датафрейма с ноутбуками

# %% [markdown]
# ### Задание 3.1
#
# Присоедините к таблице clients данные по ноутбукам через метод join

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

clients_lap_id = clients.set_index('laptop_id')
clients_lap_id
# Out:
#            client_id
# laptop_id
# 506               45
# 398               32
# 710               67
# 120               33
# 1999              43

# %%
joined = clients_lap_id.join(df)
joined
# Out:
#            client_id  laptop_ID Company                 Product     TypeName  \
# laptop_id
# 506               45      513.0    Asus  ZenBook UX510UX-CN211T     Notebook
# 398               32      405.0    Dell         Precision M5520  Workstation
# 710               67      718.0  Lenovo      Legion Y520-15IKBN       Gaming
# 120               33      123.0    Acer                  Spin 3     Notebook
# 1999              43        NaN     NaN                     NaN          NaN
#
#            Inches                          Cpu  Ram  \
# laptop_id
# 506          15.6   Intel Core i7 7500U 2.7GHz  8GB
# 398          15.6  Intel Core i7 7700HQ 2.8GHz  8GB
# 710          15.6  Intel Core i7 7700HQ 2.8GHz  8GB
# 120          15.6   Intel Core i3 7100U 2.4GHz  6GB
# 1999          NaN                          NaN  NaN
#
#                                   Gpu       OpSys  Weight  Price_euros  \
# laptop_id
# 506             Intel HD Graphics 620  Windows 10    2.00       1224.0
# 398               Nvidia Quadro M1200  Windows 10    1.78       2712.0
# 710        Nvidia GeForce GTX 1050 Ti  Windows 10    2.50       1249.0
# 120             Intel HD Graphics 620  Windows 10    2.10        479.0
# 1999                              NaN         NaN     NaN          NaN
#
#           Cpu_Company  Memory_Amount Memory_Type  SSD
# laptop_id
# 506             Intel          256.0         HDD  0.0
# 398             Intel          256.0         SSD  1.0
# 710             Intel          128.0         HDD  0.0
# 120             Intel         1024.0         HDD  0.0
# 1999              NaN            NaN         NaN  NaN

# %% [markdown]
# ### Задание 3.2
#
#  Присоедините к таблице clients данные по ноутбукам через метод merge

# %%
df['laptop_id'] = df.index
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros Cpu_Company  Memory_Amount   Memory_Type  SSD  \
# 0    1.37      1339.69       Intel            128           SSD    1
# 1    1.34       898.94       Intel            128  FlashStorage    0
# 2    1.86       575.00       Intel            256           SSD    1
# 3    1.83      2537.45       Intel            512           SSD    1
# 4    1.37      1803.60       Intel            256           SSD    1
#
#    laptop_id
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4

# %%
merged = clients.merge(df, on='laptop_id')
merged

# %% [markdown]
# ## Задание 4

# %% [markdown]
# ### Задание 4.1
#
# Найдите среднюю стоимость ноутбуков в зависимости от компании производителя

# %%
df.groupby('Company').agg({"Price_euros": 'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %% [markdown]
# ### Задание 4.2
#
# Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

# %%
df.groupby("Cpu_Company").agg({'Price_euros': ['min', 'mean', 'max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   560.638871  2199.0
# Intel             174.0  1152.214145  6099.0
# Samsung           659.0   659.000000   659.0

# %% [markdown]
# ### Задание 4.3
#
# Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ

# %%
df.pivot_table(index='Cpu_Company', columns='Ram', values='Weight', aggfunc='count', fill_value=0)
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %% [markdown]
# ### Задание 4.4
#
# Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %%
df.groupby(['OpSys', 'Memory_Amount']).agg({"Price_euros": "mean"}).unstack("Memory_Amount").fillna(0)
# Out:
#               Price_euros                                               \
# Memory_Amount        8       16          32          64           128
# OpSys
# Android               0.0    0.00    0.000000  434.000000     0.000000
# Chrome OS             0.0  305.38  412.454545  774.333333  1275.000000
# Linux                 0.0    0.00    0.000000    0.000000   742.250000
# Mac OS X              0.0    0.00    0.000000    0.000000  1099.000000
# No OS                 0.0    0.00    0.000000    0.000000   562.140000
# Windows 10         2249.0    0.00  270.001471  499.716000  1026.489167
# Windows 10 S          0.0    0.00    0.000000  308.995000  1039.000000
# Windows 7             0.0    0.00    0.000000    0.000000  1320.323333
# macOS                 0.0    0.00    0.000000    0.000000  1119.315000
#
#                                                                              \
# Memory_Amount    180     240          256         500     508          512
# OpSys
# Android           0.0     0.0     0.000000    0.000000     0.0     0.000000
# Chrome OS         0.0     0.0  1559.000000    0.000000     0.0  2199.000000
# Linux             0.0     0.0   811.638125  389.056364     0.0     0.000000
# Mac OS X          0.0     0.0  1311.994000    0.000000     0.0  1222.000000
# No OS             0.0     0.0   782.989286  404.675385     0.0  1098.500000
# Windows 10     1073.5  3100.0  1334.456872  664.717647     0.0  1911.985285
# Windows 10 S      0.0     0.0  1668.950000    0.000000     0.0  2589.000000
# Windows 7      1199.0     0.0  1846.466800  924.048333  1002.0  2235.396667
# macOS             0.0     0.0  1600.370000    0.000000     0.0  2180.870000
#
#
# Memory_Amount         1024      2048
# OpSys
# Android           0.000000    0.0000
# Chrome OS         0.000000    0.0000
# Linux           581.401290    0.0000
# Mac OS X          0.000000    0.0000
# No OS           540.539600  594.0000
# Windows 10      904.827906  666.9475
# Windows 10 S      0.000000    0.0000
# Windows 7      1539.666667    0.0000
# macOS             0.000000    0.0000

# %% [markdown]
# ## Задание 5

# %% [markdown]
# ### Задание 5.1
#
# Ноутбуков каких компаний и с каким процессором больше?

# %%
pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])

count_cpu = df.groupby(['Company', 'Cpu_Company']).size().reset_index(name='count')
max_count = count_cpu['count'].max()
count_cpu[count_cpu['count'] == max_count]
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %% [markdown]
# ### Задание 5.2
# С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
pd.crosstab(index=df['Memory_Type'], columns=df['Memory_Amount'])
# Out:
# Memory_Amount  8     16    32    64    128   180   240   256   500   508   \
# Memory_Type
# FlashStorage      0     7    38    15     4     0     0     8     0     0
# HDD               0     0     1     1    97     0     0    85   132     0
# Hybrid            0     0     0     0     0     0     0     1     0     1
# SSD               1     3     6     1    76     5     1   414     0     0
#
# Memory_Amount  512   1024  2048
# Memory_Type
# FlashStorage      2     0     0
# HDD              17   227    16
# Hybrid            1     9     0
# SSD             120    14     0
